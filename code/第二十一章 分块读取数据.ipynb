# %%
import pandas as pd

# %%
csv_file = r'../data/gapminder.csv'

# %%
chunksize=500

# %%
dataiter = pd.read_csv(csv_file, chunksize=chunksize)

# %%
a = next(dataiter)
a
# Out:
#       geo  time  adults_with_hiv_percent_age_15_49  age_at_1st_marriage_women  \
# 1500  aus  2090                                NaN                        NaN
# 1501  aus  2091                                NaN                        NaN
# 1502  aus  2092                                NaN                        NaN
# 1503  aus  2093                                NaN                        NaN
# 1504  aus  2094                                NaN                        NaN
# ...   ...   ...                                ...                        ...
# 1995  aut  1984                                NaN                        NaN
# 1996  aut  1985                                NaN                        NaN
# 1997  aut  1986                                NaN                        NaN
# 1998  aut  1987                                NaN                        NaN
# 1999  aut  1988                                NaN                        NaN
#
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
csv_database = create_engine(r'sqlite://d:/study/notebook/数据分析python数据分析/data/csv_database.db')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Windows\TEMP/ipykernel_14988/329057390.py in <module>
# ----> 1 csv_database = create_engine(r'sqlite://d:/study/notebook/数据分析python数据分析/data/csv_database.db')
#
# <string> in create_engine(url, **kwargs)
#
# D:\software\anaconda\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# D:\software\anaconda\lib\site-packages\sqlalchemy\engine\create.py in create_engine(url, **kwargs)
#     516
#     517     # create url.URL object
# --> 518     u = _url.make_url(url)
#     519
#     520     u, plugins, kwargs = u._instantiate_plugins(kwargs)
#
# ...

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv('../data/gapminder.csv')

# %%
df.head()
# Out:
#    geo  time  adults_with_hiv_percent_age_15_49  age_at_1st_marriage_women  \
# 0  afg  1700                                NaN                        NaN
# 1  afg  1800                                NaN                        NaN
# 2  afg  1801                                NaN                        NaN
# 3  afg  1802                                NaN                        NaN
# 4  afg  1803                                NaN                        NaN
#
#    aged_15_24_employment_rate_percent  aged_15_24_unemployment_rate_percent  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#    aged_15_64_labour_force_participation_rate_percent  \
# ...

# %%
df.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 537 entries, geo to yearly_co2_emissions_1000_tonnes
# dtypes: object(1), float64(535), int64(1)

# %%
radiator_df = df[df['Descriptor']=='RADIATOR']
radiator_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\software\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# D:\software\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\software\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Descriptor'
#
# The above exception was the direct cause of the following exception:
#
# ...
