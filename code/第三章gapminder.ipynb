# %%
import pandas as pd

# %%
file = r'../data/gapminder.csv'
gapminder = pd.read_csv(file, index_col=0)
gapminder.head()
# Out:
#      time  adults_with_hiv_percent_age_15_49  age_at_1st_marriage_women  \
# geo
# afg  1700                                NaN                        NaN
# afg  1800                                NaN                        NaN
# afg  1801                                NaN                        NaN
# afg  1802                                NaN                        NaN
# afg  1803                                NaN                        NaN
#
#      aged_15_24_employment_rate_percent  aged_15_24_unemployment_rate_percent  \
# geo
# afg                                 NaN                                   NaN
# afg                                 NaN                                   NaN
# afg                                 NaN                                   NaN
# afg                                 NaN                                   NaN
# afg                                 NaN                                   NaN
#
# ...

# %%
idx = {'afg':'Afghanistan'}
col = {'time':'date'}
data = gapminder.rename(index=idx, columns=col)
data.head()
# Out:
#              date  adults_with_hiv_percent_age_15_49  \
# geo
# Afghanistan  1700                                NaN
# Afghanistan  1800                                NaN
# Afghanistan  1801                                NaN
# Afghanistan  1802                                NaN
# Afghanistan  1803                                NaN
#
#              age_at_1st_marriage_women  aged_15_24_employment_rate_percent  \
# geo
# Afghanistan                        NaN                                 NaN
# Afghanistan                        NaN                                 NaN
# Afghanistan                        NaN                                 NaN
# Afghanistan                        NaN                                 NaN
# Afghanistan                        NaN                                 NaN
#
#              aged_15_24_unemployment_rate_percent  \
# geo
# Afghanistan                                   NaN
# Afghanistan                                   NaN
# ...

# %%
data = gapminder.set_index('time')
data.head()
# Out:
#       adults_with_hiv_percent_age_15_49  age_at_1st_marriage_women  \
# time
# 1700                                NaN                        NaN
# 1800                                NaN                        NaN
# 1801                                NaN                        NaN
# 1802                                NaN                        NaN
# 1803                                NaN                        NaN
#
#       aged_15_24_employment_rate_percent  \
# time
# 1700                                 NaN
# 1800                                 NaN
# 1801                                 NaN
# 1802                                 NaN
# 1803                                 NaN
#
#       aged_15_24_unemployment_rate_percent  \
# time
# 1700                                   NaN
# 1800                                   NaN
# 1801                                   NaN
# 1802                                   NaN
# 1803                                   NaN
#
# ...

# %%
new_data = data.reset_index()
new_data.head()
# Out:
#    time  adults_with_hiv_percent_age_15_49  age_at_1st_marriage_women  \
# 0  1700                                NaN                        NaN
# 1  1800                                NaN                        NaN
# 2  1801                                NaN                        NaN
# 3  1802                                NaN                        NaN
# 4  1803                                NaN                        NaN
#
#    aged_15_24_employment_rate_percent  aged_15_24_unemployment_rate_percent  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#    aged_15_64_labour_force_participation_rate_percent  \
# ...

# %%
gapminder.columns
# Out:
# Index(['geo', 'time', 'adults_with_hiv_percent_age_15_49',
#        'age_at_1st_marriage_women', 'aged_15_24_employment_rate_percent',
#        'aged_15_24_unemployment_rate_percent',
#        'aged_15_64_labour_force_participation_rate_percent',
#        'aged_15plus_employment_rate_percent',
#        'aged_15plus_labour_force_participation_rate_percent',
#        'aged_15plus_unemployment_rate_percent',
#        ...
#        'underweight_children', 'urban_population',
#        'urban_population_growth_annual_percent',
#        'urban_population_percent_of_total',
#        'urban_poverty_percent_urban_people_below_national_urban',
#        'water_and_sanitation_aid_given_percent_of_aid',
#        'water_withdrawal_cu_meters_per_person', 'wood_removal_cubic_meters',
#        'working_hours_per_week', 'yearly_co2_emissions_1000_tonnes'],
#       dtype='object', length=537)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\software\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# D:\software\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\software\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
